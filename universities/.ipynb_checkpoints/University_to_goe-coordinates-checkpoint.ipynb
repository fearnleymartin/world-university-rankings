# %%
import googlemaps
import pandas as pd
import time
import numpy as np

# %%
gmaps = googlemaps.Client (key = 'AIzaSyDFJVNWIJMny9XswQ_wOuHWh11iL7mc7uo')

# %%
df = pd.DataFrame.from_csv ('university_list_countries.csv', encoding = 'iso-8859-1')
df ['lat'] = 0
df ['lng'] = 0
df.head ()
# Out:
#        Country                            University  \
# 0  Afghanistan                     Afghan University
# 1  Afghanistan                  Al-Birony University
# 2  Afghanistan    American University of Afghanistan
# 3  Afghanistan    Aria Institute of Higher Education
# 4  Afghanistan  Ariana Institute of Higher Education
#
#                        Website  lat  lng
# 0  www.afghanuniversity.edu.af    0    0
# 1                www.au.edu.af    0    0
# 2              www.auaf.edu.af    0    0
# 3              www.aria.edu.af    0    0
# 4            www.ariana.edu.af    0    0

# %%
p = 0

for i in df.index:
    
    if (((i + 1) * 100) / df.shape [0]) > p:
        p += 1
        print (p + '% Done')
    
    result_complete = []
    try:
        result_complete = gmaps.places (df.loc [i, 'University']) ['results']
    except googlemaps.exceptions.HTTPError:
        continue
    if (len (result_complete) == 0):
        continue
    result = result_complete [0] ['geometry'] ['location']
    df.loc [i, 'lat'] = result ['lat']
    df.loc [i, 'lng'] = result ['lng']
    
df.head ()
# Out:
# 50.0% Done
# 100.0% Done
#        Country                            University  \
# 0  Afghanistan                     Afghan University
# 1  Afghanistan                  Al-Birony University
# 2  Afghanistan    American University of Afghanistan
# 3  Afghanistan    Aria Institute of Higher Education
# 4  Afghanistan  Ariana Institute of Higher Education
#
#                        Website        lat        lng
# 0  www.afghanuniversity.edu.af  34.475522  69.126454
# 1                www.au.edu.af  35.126848  69.317578
# 2              www.auaf.edu.af  34.475522  69.126454
# 3              www.aria.edu.af  27.030823  75.893719
# 4            www.ariana.edu.af  30.310454 -97.859309

# %%
df.to_csv ('University_locations.csv')

# %%
df_short = df [(df ['lat'] != 0) | (df ['lng'] != 0)]

# %%
ranks = pd.DataFrame.from_csv ('../keywords/rankfalcon_exports/weighted_rankings.csv')
ranks ['University'] = ranks.index
ranks.index = range (ranks.shape [0])
ranks.head ()
# Out:
#          Country  rank   inv_rank                         University
# 0  Massachusetts  7547  25.329307                  Boston University
# 1       New York  7445  15.952792                New York University
# 2     California  6479  15.136372                Stanford University
# 3  New Hampshire  2788  14.145092  Southern New Hampshire University
# 4       New York  4861  14.031654                Columbia University

# %%
sites = ranks ['University'].values
s_sites = df_short ['University'].values

i = 0

for s in sites:
    if s not in s_sites:
        i += 1
        
print (i)
print (i / len (sites))
# Out:
# 76
# 0.0525224602626123

# %%
df_ranked = df [[(df.loc [i, 'University'] in ranks ['University'].values) for i in df.index]]
df_ranked.shape
# Out:
# (1385, 5)

# %%
df_not_matching = ranks [[(ranks.loc [i, 'University'] in df ['University'].values) for i in ranks.index]]

# %%
df_not_matching
# Out:
#                    Country  rank   inv_rank  \
# 0            Massachusetts  7547  25.329307
# 1                 New York  7445  15.952792
# 2               California  6479  15.136372
# 3            New Hampshire  2788  14.145092
# 4                 New York  4861  14.031654
# 5                  Arizona  9988  11.856198
# 6             Pennsylvania  7932  11.231197
# 7               California  4613  11.149067
# 8            Massachusetts  5493  10.437587
# 9                 Virginia  6460  10.430589
# 10                Maryland  4912   9.846683
# 11            Pennsylvania  5403   9.739661
# 12          United Kingdom  4803   9.237788
